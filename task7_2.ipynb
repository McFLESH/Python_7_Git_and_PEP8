# %% [markdown]
# <a href="https://colab.research.google.com/github/McFLESH/practical_task_7.1/blob/main/task7_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_input():

def get_substring():

def main():
